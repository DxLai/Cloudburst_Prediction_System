# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Dataset.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                145460 non-null  object
#  1   Location            145460 non-null  object
#  2   MaximumTemperature  144199 non-null  float64
#  3   Rainfall            142199 non-null  float64
#  4   Sunshine            75625 non-null   float64
#  5   WindGustSpeed       135197 non-null  float64
#  6   Humidity9am         142806 non-null  float64
#  7   Humidity3pm         140953 non-null  float64
#  8   Pressure9am         130395 non-null  float64
#  9   Pressure3pm         130432 non-null  float64
#  10  Cloud9am            89572 non-null   float64
#  11  Cloud3pm            86102 non-null   float64
#  12  Temperature3pm      141851 non-null  float64
#  13  CloudBurst Today    142199 non-null  object
#  14  CloudBurstTomorrow  142193 non-null  object
# ...

# %%
data1 = pd.DataFrame()

# %%
data1 = data.drop(['CloudBurst Today','CloudBurstTomorrow'], axis = 1)

# %%
data2 = pd.DataFrame()
data2 = data1

# %%
data1['CBTD'] = data['CloudBurst Today']
data1['CBTM'] = data['CloudBurstTomorrow']

# %%
data2 = pd.DataFrame()
data2 = data1[data1.CBTD != 'No']
data2 = data2[data2.CBTD != np.nan]

# %%
import matplotlib.pyplot as plt

# %%
X = data2['Date']

# %% [markdown]
# ### Wind Gust Speed (x-aixis : Dates, y-axis : Wind gust speeed(m/s))

# %%
y = data2['WindGustSpeed']

# %%
plt.plot(X, y, 'o')
plt.show()

# %% [markdown]
# ### Pressure (x-aixis : Dates, y-axis : Pressure(atm))

# %%
y = data2['Pressure3pm']
plt.plot(X, y, 'o')
plt.show()

# %% [markdown]
# ### Clouds (x-aixis : Dates, y-axis : Clouds(Oktas))

# %%
y = data2['Cloud3pm']
plt.plot(X, y, 'o')
plt.show()

# %% [markdown]
# ### Temperature (x-aixis : Dates, y-axis : Temperature(℃))

# %%
y = data2['MaximumTemperature']
plt.plot(X, y, 'o')
plt.show()

# %%
y = data2['Temperature3pm']
plt.plot(X, y, 'o')
plt.show()

# %% [markdown]
# ### Humidity (x-aixis : Dates, y-axis : Humidity(%))

# %%
y = data2['Humidity3pm']
plt.plot(X, y, 'o')
plt.show()
